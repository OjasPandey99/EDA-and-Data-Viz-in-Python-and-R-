# %%
import statistics
import pandas as pd
import matplotlib.pyplot as plt
import os 
import seaborn as sns 
import numpy as np

# %%
path = os.getcwd()

# %%
msleep = pd.read_csv(path+r"\msleep.csv")
mpg = pd.read_csv(r"mpg.csv")

# %%
msleep.drop(columns={"Unnamed: 0"},inplace=True) # Dropping columns 
msleep
# Out:
#      X                        name       genus  vore         order  \
# 0    1                     Cheetah    Acinonyx     1     Carnivora
# 1    2                  Owl monkey       Aotus     4      Primates
# 2    3             Mountain beaver  Aplodontia     2      Rodentia
# 3    4  Greater short-tailed shrew     Blarina     4  Soricomorpha
# 4    5                         Cow         Bos     2  Artiodactyla
# ..  ..                         ...         ...   ...           ...
# 78  79                  Tree shrew      Tupaia     4    Scandentia
# 79  80        Bottle-nosed dolphin    Tursiops     1       Cetacea
# 80  81                       Genet     Genetta     1     Carnivora
# 81  82                  Arctic fox      Vulpes     1     Carnivora
# 82  83                     Red fox      Vulpes     1     Carnivora
#
#     conservation  Total.Sleep.Time  sleep_rem  awake   brainwt   bodywt
# 0              4              12.1    1.87541   11.9  0.281581   50.000
# ...

# %%
mpg.drop(columns={"Unnamed: 0"},inplace=True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
msleep.describe()
# Out:
#                X       vore  conservation  Total.Sleep.Time  sleep_rem  \
# count  83.000000  83.000000     83.000000         83.000000  83.000000
# mean   42.000000   2.313253      3.855422         10.433735   1.875410
# std    24.103942   1.081188      1.060747          4.450357   1.110554
# min     1.000000   1.000000      1.000000          1.900000   0.100000
# 25%    21.500000   2.000000      4.000000          7.850000   1.150000
# 50%    42.000000   2.000000      4.000000         10.100000   1.875410
# 75%    62.500000   3.000000      4.000000         13.750000   2.200000
# max    83.000000   4.000000      6.000000         19.900000   6.600000
#
#            awake    brainwt       bodywt
# count  83.000000  83.000000    83.000000
# mean   13.567470   0.281581   166.136349
# std     4.452085   0.799665   786.839732
# min     4.100000   0.000140     0.005000
# 25%    10.250000   0.006350     0.174000
# 50%    13.900000   0.115000     1.670000
# ...

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
msleep.dtypes
# Out:
# X                     int64
# name                 object
# genus                object
# vore                  int64
# order                object
# conservation          int64
# Total.Sleep.Time    float64
# sleep_rem           float64
# awake               float64
# brainwt             float64
# bodywt              float64
# dtype: object

# %%
msleep.columns  # Like names() in R
# Out:
# Index(['X', 'name', 'genus', 'vore', 'order', 'conservation',
#        'Total.Sleep.Time', 'sleep_rem', 'awake', 'brainwt', 'bodywt'],
#       dtype='object')

# %%
msleep.shape  # Like dim() in R
# Out:
# (83, 11)

# %%
msleep.isna().sum() # Counting null values in dataframe
# Out:
# X                   0
# name                0
# genus               0
# vore                0
# order               0
# conservation        0
# Total.Sleep.Time    0
# sleep_rem           0
# awake               0
# brainwt             0
# bodywt              0
# dtype: int64

# %%
msleep.duplicated().sum()
# Out:
# 0

# %%
sns.heatmap(msleep.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Univariate analysis

# %%
sns.distplot(msleep['awake'])
plt.axvline(x=np.mean(msleep['awake']),c='red',ls='--',label='mean')
plt.axvline(x=np.percentile(msleep['awake'],25),c='g',ls='--',label='25 percentile')
plt.axvline(x=np.percentile(msleep['awake'],75),c='g',ls='--',label='75 percentile')
plt.legend()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
msleep.hist(figsize =(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'X'}>,
#         <AxesSubplot:title={'center':'vore'}>,
#         <AxesSubplot:title={'center':'conservation'}>],
#        [<AxesSubplot:title={'center':'Total.Sleep.Time'}>,
#         <AxesSubplot:title={'center':'sleep_rem'}>,
#         <AxesSubplot:title={'center':'awake'}>],
#        [<AxesSubplot:title={'center':'brainwt'}>,
#         <AxesSubplot:title={'center':'bodywt'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.figure(figsize=(30,10))
sns.countplot(mpg['manufacturer'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='manufacturer', ylabel='count'>

# %%
mpg['manufacturer'].value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# subaru        14
# hyundai       14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# mercury        4
# land rover     4
# lincoln        3
# Name: manufacturer, dtype: int64

# %% [markdown]
# # Bivariate analysis

# %%
sns.regplot(mpg['cty'],mpg['hwy'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cty', ylabel='hwy'>

# %%
sns.boxplot(x=mpg['class'],y=mpg['displ'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='displ'>

# %%
sns.pairplot(mpg)

# %% [markdown]
# # Correlation analysis

# %%
round(np.corrcoef(msleep['Total.Sleep.Time'],msleep['bodywt'])[1][0],2)
# Out:
# -0.31

# %%
np.round(msleep.corr(),2)
# Out:
#                      X  vore  conservation  Total.Sleep.Time  sleep_rem  \
# X                 1.00 -0.07          0.18              0.05       0.07
# vore             -0.07  1.00         -0.02              0.11       0.05
# conservation      0.18 -0.02          1.00              0.15       0.06
# Total.Sleep.Time  0.05  0.11          0.15              1.00       0.65
# sleep_rem         0.07  0.05          0.06              0.65       1.00
# awake            -0.05 -0.11         -0.15             -1.00      -0.65
# brainwt          -0.11 -0.06          0.12             -0.29      -0.04
# bodywt           -0.08 -0.08          0.08             -0.31      -0.06
#
#                   awake  brainwt  bodywt
# X                 -0.05    -0.11   -0.08
# vore              -0.11    -0.06   -0.08
# conservation      -0.15     0.12    0.08
# Total.Sleep.Time  -1.00    -0.29   -0.31
# sleep_rem         -0.65    -0.04   -0.06
# awake              1.00     0.29    0.31
# ...

# %%
sns.heatmap(np.round(msleep.corr(),2),annot=True)
# Out:
# <AxesSubplot:>
